# %%
import numpy as np

# %%
X = np.random.rand(100,21)
X_transpose = X.transpose()
y = np.random.rand(100)

# %%
print(X)
print(X.shape)

# %%
print(X_transpose)
print(X_transpose.shape)

# %%
part1 = np.dot(X_transpose, X)
part1_inverse = np.linalg.inv(part1)

part2 = np.dot(part1_inverse, X_transpose)
W_min = np.dot(part2, y)

print(W_min.shape)
print(W_min)
# Out:
# (21,)
# [ 0.0650729  -0.06461363 -0.12846905 -0.0261478   0.00050314  0.0845857
#   0.09288812 -0.10831777  0.26544027  0.05866321 -0.02857204 -0.11029046
#   0.00948128  0.01959977  0.04533793 -0.02636668  0.17682441  0.32495802
#  -0.02947545  0.12248333  0.19877763]
